# %%
import numpy as np
import matplotlib.pyplot as plt
import rosbag

# %% [markdown]
# Read the rosbag

# %%
bag4 = rosbag.Bag('/home/shayan/shayan_ros_/src/shayan_ibvs/rosbags/bag_2024-08-07-15-40-58.bag') #without Lidar
bag5 = rosbag.Bag('/home/shayan/shayan_ros_/src/shayan_ibvs/rosbags/bag_2024-08-07-15-30-41.bag') #with 300g lidar
# bag6 = rosbag.Bag('/home/shayan/shayan_ros_/src/shayan_ibvs/rosbags/bag_2024-08-07-13-56-01.bag') #200g lidar
# bag7 = rosbag.Bag('/home/shayan/shayan_ros_/src/shayan_ibvs/rosbags/bag_2024-08-07-14-11-11.bag') #500g
# bag8 = rosbag.Bag('/home/shayan/shayan_ros_/rosbags/bag_2024-08-06-10-07-16.bag') #2m0
# bag9 = rosbag.Bag('/home/shayan/shayan_ros_/rosbags/bag_2024-08-06-10-41-54.bag') #4m0

# %%
def msg_to_np(topic_name, bag):

    norm = []
    timestamps = []
    for topic, msg, tt in bag.read_messages(topics=[topic_name]):
        timestamps.append(tt.to_sec())
        norm.append([msg.data])
    
    t = np.array(timestamps)
    # t = t - t[0]
    norm = np.array(norm)
    
    return t, norm

# %%
t ,  norm = msg_to_np('/norm', bag4)
t1, norm1 = msg_to_np('/norm', bag5)
# t2, norm2 = msg_to_np('/norm', bag6)
# t3, norm3 = msg_to_np('/norm', bag7)
# t4, norm4 = msg_to_np('/norm', bag8)
# t5, norm5 = msg_to_np('/norm', bag9)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

ax.plot(t, norm, color='blue')
ax.plot(t1, norm1, color='red', linestyle = 'dashed')
# ax.plot(t2, norm2, color='green')
# ax.plot(t3, norm3, color='magenta')
# ax.plot(t4, norm4, color='cyan')
# ax.plot(t5, norm5, color='yellow')
# ax.set_xlim([-2, 2])
# ax.set_ylim([-2, 2])
# ax.set_zlim([0, 2.5])
ax.set_xlabel('Time (seconds)', fontsize=14, weight='bold')
ax.set_ylabel(r'$\vert \vert q\vert \vert_1$', fontsize=14, weight='bold')

LL = 160; UL = 165
region_of_interest = (t > LL) & (t < UL)
region_of_interest1 = (t1 > LL) & (t1 < UL)
# region_of_interest2 = (t2 > 305) & (t2 < 335)
# region_of_interest3 = (t3 > 305) & (t3 < 335)
# region_of_interest4 = (t4 > 305) & (t4 < 335)
# region_of_interest5 = (t5 > 305) & (t5 < 335)
# Create an inset axis within the main axis
inset_ax = ax.inset_axes([0.3, 0.6, 0.2, 0.2])  # [left, bottom, width, height] in figure coordinates
inset_ax.plot(t[region_of_interest], norm[region_of_interest], color='blue')
inset_ax.plot(t1[region_of_interest1], norm1[region_of_interest1], color='red', linestyle = 'dashed')
# inset_ax.plot(t2[region_of_interest2], norm2[region_of_interest2], color='green')
# inset_ax.plot(t3[region_of_interest3], norm3[region_of_interest3], color='magenta')
# inset_ax.plot(t4[region_of_interest4], norm4[region_of_interest4], color='cyan')
# inset_ax.plot(t5[region_of_interest5], norm5[region_of_interest5], color='yellow')
ax.indicate_inset_zoom(inset_ax, edgecolor="black")


LL = 320; UL = 330
region_of_interest = (t > LL) & (t < UL)
region_of_interest1 = (t1 > LL) & (t1 < UL)
# region_of_interest2 = (t2 > LL) & (t2 < UL)
# region_of_interest3 = (t3 > LL) & (t3 < UL)
# region_of_interest4 = (t4 > LL) & (t4 < UL)
# Create an inset axis within the main axis
inset_ax = ax.inset_axes([0.56, 0.6, 0.2, 0.2])  # [left, bottom, width, height] in figure coordinates
inset_ax.plot(t[region_of_interest], norm[region_of_interest], color='blue')
inset_ax.plot(t1[region_of_interest1], norm1[region_of_interest1], color='red', linestyle = 'dashed')
# inset_ax.plot(t2[region_of_interest2], norm2[region_of_interest2], color='green')
# inset_ax.plot(t3[region_of_interest3], norm3[region_of_interest3], color='magenta')
# inset_ax.plot(t4[region_of_interest4], norm4[region_of_interest4], color='cyan')
ax.indicate_inset_zoom(inset_ax, edgecolor="black")

LL = 400; UL = 410
region_of_interest = (t > LL) & (t < UL)
region_of_interest1 = (t1 > LL) & (t1 < UL)
# region_of_interest2 = (t2 > LL) & (t2 < UL)
# region_of_interest3 = (t3 > LL) & (t3 < UL)
# region_of_interest4 = (t4 > LL) & (t4 < UL)
# Create an inset axis within the main axis
inset_ax = ax.inset_axes([0.84, 0.6, 0.15, 0.2])  # [left, bottom, width, height] in figure coordinates
inset_ax.plot(t[region_of_interest], norm[region_of_interest], color='blue')
inset_ax.plot(t1[region_of_interest1], norm1[region_of_interest1], color='red', linestyle = 'dashed')
# inset_ax.plot(t2[region_of_interest2], norm2[region_of_interest2], color='green')
# inset_ax.plot(t3[region_of_interest3], norm3[region_of_interest3], color='magenta')
# inset_ax.plot(t4[region_of_interest4], norm4[region_of_interest4], color='cyan')
ax.indicate_inset_zoom(inset_ax, edgecolor="black")

LL = 15; UL = 25
region_of_interest = (t > LL) & (t < UL)
region_of_interest1 = (t1 > LL) & (t1 < UL)
# region_of_interest2 = (t2 > LL) & (t2 < UL)
# region_of_interest3 = (t3 > LL) & (t3 < UL)
# region_of_interest4 = (t4 > LL) & (t4 < UL)
# Create an inset axis within the main axis
inset_ax = ax.inset_axes([0.1, 0.6, 0.15, 0.2])  # [left, bottom, width, height] in figure coordinates
inset_ax.plot(t[region_of_interest], norm[region_of_interest], color='blue')
inset_ax.plot(t1[region_of_interest1], norm1[region_of_interest1], color='red', linestyle = 'dashed')
# inset_ax.plot(t2[region_of_interest2], norm2[region_of_interest2], color='green')
# inset_ax.plot(t3[region_of_interest3], norm3[region_of_interest3], color='magenta')
# inset_ax.plot(t4[region_of_interest4], norm4[region_of_interest4], color='cyan')


# # Optionally, add a rectangle to show the region of interest on the main plot
ax.indicate_inset_zoom(inset_ax, edgecolor="black")
# ax.grid(visible=True)

plt.xlim([10,420])
plt.ylim([0,1])
plt.legend(['Without LiDAR','With LiDAR'], fontsize=14, ncol = 2, loc = 'upper center')
plt.savefig('norm.pdf', format='pdf')
plt.show()

# %%
def msg_to_np2(topic_name, bag):
    w = []
    timestamps = []
    for topic, msg, tt in bag.read_messages(topics=[topic_name]):
        w.append([msg.wrench.force.x,  msg.wrench.force.y,  msg.wrench.force.z,
                msg.wrench.torque.x, msg.wrench.torque.y, msg.wrench.torque.z])
        timestamps.append(tt.to_sec())

    tt = np.array(timestamps)
    tt = tt - tt[0]
    w = np.array(w)
    return tt, w

# %%
tt ,  w = msg_to_np2('/command/wrench', bag4)
tt1 ,  w1 = msg_to_np2('/command/wrench', bag5)
tt2 ,  w2 = msg_to_np2('/command/wrench', bag7)

# %%
fig = plt.figure(figsize = (12, 6))

ax = fig.add_subplot(411)
ax.plot(tt,w[:, 2], color = 'blue')
ax.plot(tt1,w1[:, 2], color = 'red', linestyle = 'dashed')
ax.plot(tt2,w2[:, 2], color = 'green', linestyle = 'dashed')
ax.set_xlabel('Time (seconds)', fontsize=14, weight='bold')
ax.set_ylabel(r'$f_z$ (N)', fontsize = 14, weight = 'bold')
ax.grid(visible = True)
ax.set_xlim([0, 20])
# ax.set_ylim([-0.7, 0.7])
plt.xticks(fontsize=14, weight='bold')
plt.yticks(fontsize=14, weight='bold')

ax = fig.add_subplot(412)
ax.plot(tt,w[:, 3], color = 'blue')
ax.plot(tt1,w1[:, 3], color = 'red', linestyle = 'dashed')
ax.plot(tt2,w2[:, 3], color = 'green', linestyle = 'dashed')
ax.set_xlabel('Time (seconds)', fontsize=14, weight='bold')
ax.set_ylabel(r'$\tau_{\phi}$ (N.m)', fontsize = 14, weight = 'bold')
ax.grid(visible = True)
ax.set_xlim([0, 420])
# ax.set_ylim([-0.7, 0.7])
plt.xticks(fontsize=14, weight='bold')
# plt.yticks(fontsize=14, weight='bold')
# # ax.fill_between(t,-0.5, 0.5, where=[(xi >= 0 and xi <= 80) for xi in t], color='burlywood', alpha=0.6)
# # ax.fill_between(t,-0.5, 0.5, where=[(xi >= 80) for xi in t], color='lightblue', alpha=0.6)

ax = fig.add_subplot(413)
ax.plot(tt,w[:, 4], color = 'blue')
ax.plot(tt1,w1[:, 4], color = 'red', linestyle = 'dashed')
ax.set_xlabel('Time (seconds)', fontsize=14, weight='bold')
ax.set_ylabel(r'$\tau_{\theta}$ (N.m)', fontsize = 14, weight = 'bold')
ax.grid(visible = True)
ax.set_xlim([0, 420])
# ax.set_ylim([-0.7, 0.7])
plt.xticks(fontsize=14, weight='bold')
plt.yticks(fontsize=14, weight='bold')

# ax = fig.add_subplot(414)
# ax.plot(tt,w[:, 5], color = 'blue')
# # ax.plot(t1,w1[:, 5], color = 'red', linestyle = 'dashed')
# ax.set_xlabel('Time (seconds)', fontsize=14, weight='bold')
# ax.set_ylabel(r'$\tau_{\psi}$ (N.m)', fontsize = 14, weight = 'bold')
# ax.grid(visible = True)
# ax.set_xlim([0, 420])
# # ax.set_ylim([-0.7, 0.7])

plt.xticks(fontsize=14, weight='bold')
plt.yticks(fontsize=14, weight='bold')

plt.tight_layout()
plt.subplots_adjust(hspace=0.6)
plt.show
# plt.savefig('control_input.eps', format='eps')

# %%
# Do Not delete
bag4.close()
bag5.close()
bag6.close()
